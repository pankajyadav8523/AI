# %% [markdown]
# $$BFS$$
# The Breadth First Search (BFS) algorithm is used to search a graph data structure for a node that meets a set of criteria. It starts at the root of the graph and visits all nodes at the current depth level before moving on to the nodes at the next depth level.
#
#
#
# *   It searches level by level of graph or tree.
# *   In BFS, We search the tree by levels start from level 0 go to the level 1 then level 2 and so on.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   Algorithm has three component -
# *   Graph Traversal : We will traverse the whole graph or tree . In addition we will take as an input node.
# *   We take two nodes, find the second node by using BFS and we will stop to traverse after getting node in the graph.
# *   We will create the list to store the path of node1 to node2

# %%
# Algoritham of BFS for implementing

# By default our tree or graph is undirected
# First visit any default node given already in quie_list
# Find it's adjacent vertices and append it into quie_list
# Remove visited node from quie_list and append one by one into visited_list.
# We will append those nodes in quie_list, which is not in visited_list.

# %%
# %run random_graph.ipynb #import random graph module
adj_list = G.adjList() # making adjacency list
# Out:
# Maximum dropout can be :-  0.9782716049382716
# Removing Edges: 1028it [00:36, 28.38it/s]
# Shortest path from Rajsamand to Patna: ['Rajsamand', 'Prayagraj', 'Patna']
# Shortest path length: 1321
# {'Agra': [('Una', 610), ('Lakhimpur', 363), ('Daudnagar', 800), ('Sitamarhi', 887), ('Morena', 82), ('Agra', 0), ('Pakur', 1218), ('Baghpat', 270), ('Nawada', 931), ('Mirzapur', 567), ('Ghazipur', 677), ('Jaipur', 239), ('Durgapur', 1104), ('Aligarh', 91), ('Palamu', 886), ('Araria', 1098), ('Calicut', 2233), ('Jehanabad', 872), ('Bhagalpur', 1070)], 'Aligarh': [('Agra', 91), ('Raebareli', 404), ('Patna', 842), ('Kota', 446), ('Sikar', 358), ('Prayagraj', 501), ('Sarangarh', 1095), ('Lakhimpur', 328), ('Arrah', 790), ('Belagavi', 1660), ('Sitamarhi', 890), ('Sitapur', 306), ('Delhi', 163), ('Faridabad', 117), ('Mahoba', 444), ('Baghpat', 165), ('Bikaner', 525), ('Mirzapur', 597), ('Jaipur', 284), ('Durgapur', 1133), ('Rohtas', 773), ('Palamu', 916), ('Sri Ganganagar', 588)], 'Araria': [('Agra', 1098), ('Raebareli', 731), ('Sikar', 1448), ('Prayagraj', 673), ('Bundi', 1428), ('Madhepura', 131), ('Arrah', 355), ('Hanamkonda', 1647), ('Sitamarhi', 238), ('Sitapur', 853), ('Faridabad', 1272), ('Mahoba', 911), ('Sagar', 1126), ('Bikaner', 1666), ('Ghazipur', 470), ('Durgapur', 382), ('Palamu', 573), ('Araria', 0), ('Calicut', 2617), ('Jehanabad', 362), ('Sri Ganganagar', 1716)], 'Arrah': [('Aligarh', 790), ('Araria', 355), ('Patna', 52), ('Gaya', 130), ('Kota', 1086), ('Sikar', 1138), ('Prayagraj', 308), ('Bhopal', 940), ('Sarangarh', 639), ('Lakhimpur', 595), ('Arrah', 0), ('Belagavi', 1820), ('Hanamkonda', 1321), ('Delhi', 964), ('Pakur', 432), ('Bikaner', 1356), ('Jaipur', 1024), ('Chitrakoot', 445), ('Calicut', 2328), ('Jehanabad', 80), ('Sri Ganganagar', 1406), ('Balaghat', 855)], 'Baghpat': [('Agra', 270), ('Aligarh', 165), ('Lucknow', 496), ('Gaya', 1037), ('Prayagraj', 664), ('Una', 348), ('Lakhimpur', 430), ('Daudnagar', 966), ('Hanamkonda', 1520), ('Sitamarhi', 1053), ('Morena', 345), ('Delhi', 48), ('Jodhpur', 593), ('Pakur', 1384), ('Mirzapur', 760), ('Ghazipur', 843), ('Calicut', 2442), ('Bhagalpur', 1236)], 'Balaghat': [('Arrah', 855), ('Lucknow', 732), ('Rajsamand', 999), ('Raebareli', 655), ('Gaya', 885), ('Kota', 768), ('Sikar', 1107), ('Una', 1400), ('Bundi', 801), ('Sarangarh', 439), ('Lakhimpur', 902), ('Madhepura', 1079), ('Hanamkonda', 538), ('Sitamarhi', 1026), ('Sitapur', 861), ('Sagar', 353), ('Ghazipur', 756), ('Chitrakoot', 504), ('Rohtas', 794), ('Bhagalpur', 1123)], 'Belagavi': [('Aligarh', 1660), ('Arrah', 1820), ('Lucknow', 1717), ('Rajsamand', 1269), ('Raebareli', 1617), ('Gaya', 1865), ('Bhopal', 1086), ('Una', 2068), ('Sarangarh', 1384), ('Daudnagar', 1794), ('Belagavi', 0), ('Hanamkonda', 737), ('Sitapur', 1809), ('Jodhpur', 1457), ('Sagar', 1260), ('Mirzapur', 1576), ('Ghazipur', 1718), ('Jaipur', 1463), ('Durgapur', 2000), ('Chitrakoot', 1466), ('Palamu', 1711), ('Bhagalpur', 2100), ('Sri Ganganagar', 1878)], 'Bhagalpur': [('Agra', 1070), ('Baghpat', 1236), ('Balaghat', 1123), ('Belagavi', 2100), ('Lucknow', 735), ('Kota', 1369), ('Sikar', 1421), ('Prayagraj', 591), ('Bundi', 1401), ('Sarangarh', 780), ('Madhepura', 186), ('Hanamkonda', 1542), ('Sitamarhi', 302), ('Sitapur', 826), ('Delhi', 1248), ('Faridabad', 1244), ('Jodhpur', 1638), ('Sagar', 1055), ('Mirzapur', 525), ('Ghazipur', 405), ('Chitrakoot', 728), ('Palamu', 454), ('Jehanabad', 225)], 'Bhopal': [('Arrah', 940), ('Belagavi', 1086), ('Gaya', 986), ('Kota', 341), ('Bhopal', 0), ('Una', 1156), ('Sarangarh', 748), ('Madhepura', 1164), ('Daudnagar', 915), ('Delhi', 783), ('Mahoba', 383), ('Pakur', 1362), ('Ghazipur', 821), ('Jaipur', 593), ('Jehanabad', 987), ('Sri Ganganagar', 1050)], 'Bikaner': [('Aligarh', 525), ('Araria', 1666), ('Arrah', 1356), ('Raebareli', 926), ('Patna', 1363), ('Gaya', 1396), ('Prayagraj', 1042), ('Bundi', 439), ('Sarangarh', 1543), ('Morena', 622), ('Delhi', 423), ('Faridabad', 445), ('Jodhpur', 253), ('Pakur', 1743), ('Mirzapur', 1138), ('Ghazipur', 1202), ('Durgapur', 1674), ('Rohtas', 1298), ('Calicut', 2314)], 'Bundi': [('Araria', 1428), ('Balaghat', 801), ('Bhagalpur', 1401), ('Bikaner', 439), ('Rajsamand' ...

# %% [markdown]
# $$ Full \quad Graph \quad Traversal $$

# %%
# BFS traverse
node = input("Enter the starting or root node :")

quie_list = [node]
visited_list = [node]


def BFS(node):
  j = 1
  while j <= len(quie_list):
    for i in adj_list[quie_list[0]]:
      if i[0] not in visited_list:
        quie_list.append(i[0])
        visited_list.append(i[0])
    quie_list.pop(0)

  print(visited_list)

BFS(node)
# Out:
# ['Agra', 'Una', 'Lakhimpur', 'Daudnagar', 'Sitamarhi', 'Morena', 'Pakur', 'Baghpat', 'Nawada', 'Mirzapur', 'Ghazipur', 'Jaipur', 'Durgapur', 'Aligarh', 'Palamu', 'Araria', 'Calicut', 'Jehanabad', 'Bhagalpur', 'Balaghat', 'Belagavi', 'Bhopal', 'Chitrakoot', 'Hanamkonda', 'Kota', 'Lucknow', 'Mahoba', 'Patna', 'Prayagraj', 'Raebareli', 'Sikar', 'Arrah', 'Faridabad', 'Jodhpur', 'Sarangarh', 'Madhepura', 'Sri Ganganagar', 'Sagar', 'Bundi', 'Delhi', 'Rajsamand', 'Sitapur', 'Bikaner', 'Gaya', 'Rohtas']

# %% [markdown]
# Stoping, After Finding node

# %%
# BFS, Finding target node
node1 = input("Enter the starting node :")
node2 = input("Enter the goal node :")

def BFS_target(node1, node2):
  quie_list = [node1]
  visited_list  = [node1]
  j = 1
  while j <= len(quie_list):
    for i in adj_list[quie_list[0]]:
      if i[0] == node2:
        #return node2
        return
      else:
        if i[0] not in visited_list:
          quie_list.append(i[0])
          visited_list.append(i[0])
    quie_list.pop(0)

BFS_target(node1, node2)

# %% [markdown]
#  Finding Path from node1 to node2

# %%
# BFS, Finding target path
node1 = input("Enter the starting node :")
node2 = input("Enter the goal node :")

def BFS_target(node1, node2):
    queue_list = [[node1]]
    visited_list = [node1]

    while queue_list:
        path = queue_list.pop(0)
        current_node = path[-1]

        if current_node == node2:
            return path  # Return the path when the target node is reached

        for neighbor in adj_list[current_node]:
            if neighbor[0] not in visited_list:
                visited_list.append(neighbor[0])
                new_path = list(path)  # Create a copy of the current path
                new_path.append(neighbor[0])
                queue_list.append(new_path)

    return None  # If no path is found, return None


print(BFS_target(node1, node2))
# Out:
# None
