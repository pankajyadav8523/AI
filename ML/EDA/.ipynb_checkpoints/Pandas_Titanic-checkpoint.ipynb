# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].std()
# Out:
# 14.526497332334042

# %%
df["Age"].median()
# Out:
# 28.0

# %%
df["Age"].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df["Age"].count()
# Out:
# 714

# %%
df["Age"].nunique()
# Out:
# 88

# %%
df["Fare"].mean()
# Out:
# 32.204207968574636

# %%
df["Fare"].max()
# Out:
# 512.3292

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df[["Sex", "Survived"]].value_counts()
# Out:
# Sex     Survived
# male    0           468
# female  1           233
# male    1           109
# female  0            81
# Name: count, dtype: int64

# %%
df["Age_Months"] = df["Age"]*12

# %%
df["Age_Months"]
# Out:
# 0      264.0
# 1      456.0
# 2      312.0
# 3      420.0
# 4      420.0
#        ...
# 886    324.0
# 887    228.0
# 888      NaN
# 889    312.0
# 890    384.0
# Name: Age_Months, Length: 891, dtype: float64

# %%
df["Age_Months"].mean()
# Out:
# 356.38941176470587

# %%
len(df)
# Out:
# 891

# %%
#Accessing the row by using row number
df.iloc[542]
# Out:
# PassengerId                                  543
# Survived                                       0
# Pclass                                         3
# Name           Andersson, Miss. Sigrid Elisabeth
# Sex                                       female
# Age                                         11.0
# SibSp                                          4
# Parch                                          2
# Ticket                                    347082
# Fare                                      31.275
# Cabin                                        NaN
# Embarked                                       S
# Age_Months                                 132.0
# Name: 542, dtype: object

# %%
#Accessing the row using the index number
df.loc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Age_Months                                                 456.0
# Name: 1, dtype: object

# %%
df.iloc[647]
# Out:
# PassengerId                                    648
# Survived                                         1
# Pclass                                           1
# Name           Simonius-Blumer, Col. Oberst Alfons
# Sex                                           male
# Age                                           56.0
# SibSp                                            0
# Parch                                            0
# Ticket                                       13213
# Fare                                          35.5
# Cabin                                          A26
# Embarked                                         C
# Age_Months                                   672.0
# Name: 647, dtype: object

# %%
df.loc[648]
# Out:
# PassengerId                   649
# Survived                        0
# Pclass                          3
# Name           Willey, Mr. Edward
# Sex                          male
# Age                           NaN
# SibSp                           0
# Parch                           0
# Ticket              S.O./P.P. 751
# Fare                         7.55
# Cabin                         NaN
# Embarked                        S
# Age_Months                    NaN
# Name: 648, dtype: object

# %%
df.loc[647]
# Out:
# PassengerId                                    648
# Survived                                         1
# Pclass                                           1
# Name           Simonius-Blumer, Col. Oberst Alfons
# Sex                                           male
# Age                                           56.0
# SibSp                                            0
# Parch                                            0
# Ticket                                       13213
# Fare                                          35.5
# Cabin                                          A26
# Embarked                                         C
# Age_Months                                   672.0
# Name: 647, dtype: object

# %%
# Changed the index with the Ticket Number
df.index = df["Ticket"]

# %%
df.loc["211536"]
# Out:
# PassengerId                      887
# Survived                           0
# Pclass                             2
# Name           Montvila, Rev. Juozas
# Sex                             male
# Age                             27.0
# SibSp                              0
# Parch                              0
# Ticket                        211536
# Fare                            13.0
# Cabin                            NaN
# Embarked                           S
# Age_Months                     324.0
# Name: 211536, dtype: object

# %%
#Two rows can have the same index
df.loc["W./C. 6607"]
# Out:
#             PassengerId  Survived  Pclass  \
# Ticket
# W./C. 6607          784         0       3
# W./C. 6607          889         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# Ticket
# W./C. 6607                    Johnston, Mr. Andrew G    male  NaN      1
# W./C. 6607  Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1
#
#             Parch      Ticket   Fare Cabin Embarked  Age_Months
# Ticket
# W./C. 6607      2  W./C. 6607  23.45   NaN        S         NaN
# W./C. 6607      2  W./C. 6607  23.45   NaN        S         NaN

# %%
df.loc["STON/O2. 3101282"]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Age_Months                      312.0
# Name: STON/O2. 3101282, dtype: object

# %%
# Reset the index to its original state
df.reset_index(drop = True, inplace = True)

# %%
df.loc[400]
# Out:
# PassengerId                   401
# Survived                        1
# Pclass                          3
# Name           Niskanen, Mr. Juha
# Sex                          male
# Age                          39.0
# SibSp                           0
# Parch                           0
# Ticket          STON/O 2. 3101289
# Fare                        7.925
# Cabin                         NaN
# Embarked                        S
# Age_Months                  468.0
# Name: 400, dtype: object

# %%
df.iloc[400]
# Out:
# PassengerId                   401
# Survived                        1
# Pclass                          3
# Name           Niskanen, Mr. Juha
# Sex                          male
# Age                          39.0
# SibSp                           0
# Parch                           0
# Ticket          STON/O 2. 3101289
# Fare                        7.925
# Cabin                         NaN
# Embarked                        S
# Age_Months                  468.0
# Name: 400, dtype: object

# %%
df.loc[399]
# Out:
# PassengerId                                 400
# Survived                                      1
# Pclass                                        2
# Name           Trout, Mrs. William H (Jessie L)
# Sex                                      female
# Age                                        28.0
# SibSp                                         0
# Parch                                         0
# Ticket                                   240929
# Fare                                      12.65
# Cabin                                       NaN
# Embarked                                      S
# Age_Months                                336.0
# Name: 399, dtype: object

# %%
df.iloc[399]
# Out:
# PassengerId                                 400
# Survived                                      1
# Pclass                                        2
# Name           Trout, Mrs. William H (Jessie L)
# Sex                                      female
# Age                                        28.0
# SibSp                                         0
# Parch                                         0
# Ticket                                   240929
# Fare                                      12.65
# Cabin                                       NaN
# Embarked                                      S
# Age_Months                                336.0
# Name: 399, dtype: object

# %%
df2 = df[df["Age"]<=10]

# %%
df2
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                   Boulos, Miss. Nourelain
# 869          870         1       3           Johnson, Master. Harold Theodor
#
# ...

# %%
df2["Age"]
# Out:
# 7      2.00
# 10     4.00
# 16     2.00
# 24     8.00
# 43     3.00
#        ...
# 827    1.00
# 831    0.83
# 850    4.00
# 852    9.00
# 869    4.00
# Name: Age, Length: 64, dtype: float64

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Age_Months'],
#       dtype='object')

# %%
df2[["Age", "Name", "Sex"]]
# Out:
#       Age                                      Name     Sex
# 7    2.00            Palsson, Master. Gosta Leonard    male
# 10   4.00           Sandstrom, Miss. Marguerite Rut  female
# 16   2.00                      Rice, Master. Eugene    male
# 24   8.00             Palsson, Miss. Torborg Danira  female
# 43   3.00  Laroche, Miss. Simonne Marie Anne Andree  female
# ..    ...                                       ...     ...
# 827  1.00                     Mallet, Master. Andre    male
# 831  0.83           Richards, Master. George Sibley    male
# 850  4.00   Andersson, Master. Sigvard Harald Elias    male
# 852  9.00                   Boulos, Miss. Nourelain  female
# 869  4.00           Johnson, Master. Harold Theodor    male
#
# [64 rows x 3 columns]

# %%
df[df["Fare"] <= 20]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df["Sex"] == "male") & (df["Fare"] <= 20)]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# 17            18         1       2    Williams, Mr. Charles Eugene  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  Age_Months
# ...

# %%
df3 = df[(df["Sex"] == "female") & (df["Age"] >= 50)]

# %%
len(df3)
# Out:
# 22

# %%
df[(df["Survived"] == 1) & (df["Age"] >= 40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 52            53         1       1
# 161          162         1       2
# 187          188         1       1
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 161  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...  female  40.0      0
# 187      Romaine, Mr. Charles Hallace ("Mr C Rolmane")    male  45.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4 = df[(df["Sex"] == "female") | (df["Age"] <= 10)]

# %%
len(df4)
# Out:
# 347

# %%
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 7              8         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df["Survived"] == 0) | (df["Sex"] == "female")]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Ticket"] == "347082"]
# Out:
#      PassengerId  Survived  Pclass  \
# 13            14         0       3
# 119          120         0       3
# 541          542         0       3
# 542          543         0       3
# 610          611         0       3
# 813          814         0       3
# 850          851         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 541               Andersson, Miss. Ingeborg Constanzia  female   9.0      4
# 542                  Andersson, Miss. Sigrid Elisabeth  female  11.0      4
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0      1
# 813                 Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 850            Andersson, Master. Sigvard Harald Elias    male   4.0      4
#
#      Parch  Ticket    Fare Cabin Embarked  Age_Months
# ...

# %%
df.drop(610, inplace = True) # Deleting the duplicate row

# %%
df[df["Ticket"] == "347082"]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 13            14         0       3              Andersson, Mr. Anders Johan
# 119          120         0       3        Andersson, Miss. Ellis Anna Maria
# 541          542         0       3     Andersson, Miss. Ingeborg Constanzia
# 542          543         0       3        Andersson, Miss. Sigrid Elisabeth
# 813          814         0       3       Andersson, Miss. Ebba Iris Alfrida
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
#
#         Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked  Age_Months
# 13     male  39.0      1      5  347082  31.275   NaN        S       468.0
# 119  female   2.0      4      2  347082  31.275   NaN        S        24.0
# 541  female   9.0      4      2  347082  31.275   NaN        S       108.0
# 542  female  11.0      4      2  347082  31.275   NaN        S       132.0
# ...

# %%
df.drop("Age_Months", axis = 1, inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df5 = df[df["Sex"] == "male"] # mean age of people who are male

# %%
df5["Age"].mean()
# Out:
# 30.72664459161148

# %%
df6 = df[df["Sex"] == "female"]

# %%
df6["Fare"].min()
# Out:
# 6.75

# %%
df["Ticket"].value_counts()
# Out:
# Ticket
# CA. 2343    7
# 1601        7
# 3101295     6
# 347082      6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
df["Ticket"].value_counts().max() # max no. of passengers travelling on the same ticket
# Out:
# 7

# %%
df.info() # to find the no. of missing values (NaN)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 890 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  890 non-null    int64
#  1   Survived     890 non-null    int64
#  2   Pclass       890 non-null    int64
#  3   Name         890 non-null    object
#  4   Sex          890 non-null    object
#  5   Age          713 non-null    float64
#  6   SibSp        890 non-null    int64
#  7   Parch        890 non-null    int64
#  8   Ticket       890 non-null    object
#  9   Fare         890 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     888 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.4+ KB

# %%
df[df["Cabin"].notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Cabin"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[df["Cabin"].isnull()]["Fare"].mean()
# Out:
# 19.1396610787172

# %%
df[df["Cabin"].notnull()]["Age"].mean()
# Out:
# 35.829297297297295

# %%
df7 = df[(df["Sex"] == "female") & (df["Age"].isnull())]

# %%
len(df7)
# Out:
# 53

# %%
# For operations on all columns
# df.agg(['mean', 'max', 'min'])

# %%
df.agg({'Age':["min", "max", "median", "mean"], "Fare":["min", "max", "median", "mean"]})
# Out:
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# mean    29.686073   32.205252

# %%
df.agg({'Age':["min", "max", "median", "mean"], "Fare":["min", "max", "median"]})
# Out:
#               Age      Fare
# min      0.420000    0.0000
# max     80.000000  512.3292
# median  28.000000   14.4542
# mean    29.686073       NaN

# %%
df.groupby('Sex').agg({'Age':'mean'})
# Out:
#               Age
# Sex
# female  27.873077
# male    30.726645

# %%
df.groupby('Age').agg({'Fare':'mean'})
# Out:
#            Fare
# Age
# 0.42     8.5167
# 0.67    14.5000
# 0.75    19.2583
# 0.83    23.8750
# 0.92   151.5500
# ...         ...
# 70.00   40.7500
# 70.50    7.7500
# 71.00   42.0792
# 74.00    7.7750
# 80.00   30.0000
#
# [88 rows x 1 columns]

# %%
df.groupby(['Age', 'Survived']).agg({'Fare':'mean'})
# Out:
#                     Fare
# Age   Survived
# 0.42  1           8.5167
# 0.67  1          14.5000
# 0.75  1          19.2583
# 0.83  1          23.8750
# 0.92  1         151.5500
# ...                  ...
# 70.00 0          40.7500
# 70.50 0           7.7500
# 71.00 0          42.0792
# 74.00 0           7.7750
# 80.00 1          30.0000
#
# [142 rows x 1 columns]

# %%
df[df["Sex"] == "male"].groupby("Survived")["Age"].max()
# Out:
# Survived
# 0    74.0
# 1    80.0
# Name: Age, dtype: float64

# %%
result = df[df["Sex"] == "male"].groupby(df[df["Sex"] == "male"]["Survived"] == 1)["Age"].max()

# %%
print(result)
# Out:
# Survived
# False    74.0
# True     80.0
# Name: Age, dtype: float64

# %%
df[df["Sex"] == "male"].groupby(df["Survived"] == 1).agg({"Age":"max"})
# Out:
#            Age
# Survived
# False     74.0
# True      80.0

# %%
df[df["Age"].isnull() ]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df[df["Name"] == "Razi, Mr. Raihed"].index[0]
# Out:
# 859

# %%
df.loc[859, "Age"] = 38.0 # Updating the value of age

# %%
df[df["Name"] == "Razi, Mr. Raihed"]
# Out:
#      PassengerId  Survived  Pclass              Name   Sex   Age  SibSp  \
# 859          860         0       3  Razi, Mr. Raihed  male  38.0      0
#
#      Parch Ticket    Fare Cabin Embarked
# 859      0   2629  7.2292   NaN        C

# %%
df[df["Sex"] == "male"].index[97]
# Out:
# 153

# %%
# for appending  column to the dataframe 
# df["new_column"] = value_list

# %%
#for appending row to the dataframe 
# df.loc[index] = value_list

# %%
df["Age_Months"] = df["Age"]*12

# %%
df["Age_Months"]
# Out:
# 0      264.0
# 1      456.0
# 2      312.0
# 3      420.0
# 4      420.0
#        ...
# 886    324.0
# 887    228.0
# 888      NaN
# 889    312.0
# 890    384.0
# Name: Age_Months, Length: 890, dtype: float64

# %%
df.loc[891] = [1, 3, 5, 2, 4,5 ,5, 78,6, 7, 9, 8, 7]

# %%
df.loc[891]
# Out:
# PassengerId      1
# Survived         3
# Pclass           5
# Name             2
# Sex              4
# Age            5.0
# SibSp            5
# Parch           78
# Ticket           6
# Fare           7.0
# Cabin            9
# Embarked         8
# Age_Months     7.0
# Name: 891, dtype: object

# %%
len(df.columns)
# Out:
# 13

# %%
df.drop(891, inplace = True)

# %%
df1 = df[["Name", "Age"]]

# %%
df2 = df[["Name", "Ticket"]]

# %%
df1
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [890 rows x 2 columns]

# %%
df2
# Out:
#                                                   Name            Ticket
# 0                              Braund, Mr. Owen Harris         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                               Heikkinen, Miss. Laina  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                             Allen, Mr. William Henry            373450
# ..                                                 ...               ...
# 886                              Montvila, Rev. Juozas            211536
# 887                       Graham, Miss. Margaret Edith            112053
# 888           Johnston, Miss. Catherine Helen "Carrie"        W./C. 6607
# 889                              Behr, Mr. Karl Howell            111369
# 890                                Dooley, Mr. Patrick            370376
#
# [890 rows x 2 columns]

# %%
df_inner = pd.merge(df1, df2, on = "Name", how = "inner")

# %%
df_inner
# Out:
#                                                   Name   Age            Ticket
# 0                              Braund, Mr. Owen Harris  22.0         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0          PC 17599
# 2                               Heikkinen, Miss. Laina  26.0  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0            113803
# 4                             Allen, Mr. William Henry  35.0            373450
# ..                                                 ...   ...               ...
# 885                              Montvila, Rev. Juozas  27.0            211536
# 886                       Graham, Miss. Margaret Edith  19.0            112053
# 887           Johnston, Miss. Catherine Helen "Carrie"   NaN        W./C. 6607
# 888                              Behr, Mr. Karl Howell  26.0            111369
# 889                                Dooley, Mr. Patrick  32.0            370376
#
# [890 rows x 3 columns]

# %%
df_left = pd.merge(df1, df2, on = "Name", how = "left")

# %%
df_left
# Out:
#                                                   Name   Age            Ticket
# 0                              Braund, Mr. Owen Harris  22.0         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0          PC 17599
# 2                               Heikkinen, Miss. Laina  26.0  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0            113803
# 4                             Allen, Mr. William Henry  35.0            373450
# ..                                                 ...   ...               ...
# 885                              Montvila, Rev. Juozas  27.0            211536
# 886                       Graham, Miss. Margaret Edith  19.0            112053
# 887           Johnston, Miss. Catherine Helen "Carrie"   NaN        W./C. 6607
# 888                              Behr, Mr. Karl Howell  26.0            111369
# 889                                Dooley, Mr. Patrick  32.0            370376
#
# [890 rows x 3 columns]

# %%
df_right = pd.merge(df1, df2, on = "Name", how = "right")

# %%
df_right
# Out:
#                                                   Name   Age            Ticket
# 0                              Braund, Mr. Owen Harris  22.0         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0          PC 17599
# 2                               Heikkinen, Miss. Laina  26.0  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0            113803
# 4                             Allen, Mr. William Henry  35.0            373450
# ..                                                 ...   ...               ...
# 885                              Montvila, Rev. Juozas  27.0            211536
# 886                       Graham, Miss. Margaret Edith  19.0            112053
# 887           Johnston, Miss. Catherine Helen "Carrie"   NaN        W./C. 6607
# 888                              Behr, Mr. Karl Howell  26.0            111369
# 889                                Dooley, Mr. Patrick  32.0            370376
#
# [890 rows x 3 columns]

# %%
df_outer = pd.merge(df1, df2, on = "Name", how = "outer")

# %%
df_outer
# Out:
#                                                   Name   Age            Ticket
# 0                              Braund, Mr. Owen Harris  22.0         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0          PC 17599
# 2                               Heikkinen, Miss. Laina  26.0  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0            113803
# 4                             Allen, Mr. William Henry  35.0            373450
# ..                                                 ...   ...               ...
# 885                              Montvila, Rev. Juozas  27.0            211536
# 886                       Graham, Miss. Margaret Edith  19.0            112053
# 887           Johnston, Miss. Catherine Helen "Carrie"   NaN        W./C. 6607
# 888                              Behr, Mr. Karl Howell  26.0            111369
# 889                                Dooley, Mr. Patrick  32.0            370376
#
# [890 rows x 3 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   890.000000  890.000000  890.000000  714.000000  890.000000
# mean    445.814607    0.384270    2.307865   29.697717    0.522472
# std     257.439006    0.486696    0.836220   14.525648    1.103247
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.250000    0.000000    2.000000   20.125000    0.000000
# 50%     445.500000    0.000000    3.000000   28.000000    0.000000
# 75%     668.750000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  Age_Months
# count  890.000000  890.000000  714.000000
# mean     0.376404   32.205252  356.372605
# std      0.791479   49.721360  174.307770
# min      0.000000    0.000000    5.040000
# 25%      0.000000    7.903100  241.500000
# 50%      0.000000   14.454200  336.000000
# 75%      0.000000   31.000000  456.000000
# ...

# %%
df3 = df.describe()

# %%
df3.loc["25%"]["Age"]
# Out:
# 20.125

# %%
df.sample(n=190)
# Out:
#      PassengerId  Survived  Pclass  \
# 339          340         0       1
# 515          516         0       1
# 874          875         1       2
# 423          424         0       3
# 860          861         0       3
# ..           ...       ...     ...
# 603          604         0       3
# 238          239         0       2
# 552          553         0       3
# 309          310         1       1
# 800          801         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 339                       Blackwell, Mr. Stephen Weart    male  45.0      0
# 515                       Walker, Mr. William Anderson    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 423  Danbom, Mrs. Ernst Gilbert (Anna Sigrid Maria ...  female  28.0      1
# 860                            Hansen, Mr. Claus Peter    male  41.0      2
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked  Age_Months
# 0      0         A/5 21171   7.2500   NaN        S       264.0
# 1      0          PC 17599  71.2833   C85        C       456.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       312.0
# 3      0            113803  53.1000  C123        S       420.0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[0:4, 2:5]
# Out:
#    Pclass                                               Name     Sex
# 0       3                            Braund, Mr. Owen Harris    male
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2       3                             Heikkinen, Miss. Laina  female
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
